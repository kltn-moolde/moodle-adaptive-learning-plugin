# %%
import csv

def check_q_values(file_path):
    with open(file_path, mode='r', encoding='utf-8') as file:
        reader = csv.reader(file)
        header = next(reader)  # Bỏ qua tiêu đề cột
        found = False
        
        for line_number, row in enumerate(reader, start=2):  # start=2 vì dòng 1 là header
            try:
                q_value = float(row[-1])  # Cột q_value nằm ở cuối
                if q_value > 0:
                    print(f"Dòng {line_number}: {row}")
                    found = True
            except ValueError:
                print(f"Lỗi: Không thể chuyển q_value ở dòng {line_number} thành số.")
        
        if not found:
            print("Không có dòng nào có q_value > 0.")

# Gọi hàm
check_q_values("q_table_results.csv")
# Out:
# Dòng 120: ['38', 'easy', '0.6', '8', 'do_quiz_easier', '0.31200000000000006']
# Dòng 476: ['39', 'easy', '0.6', '8', 'attempt_new_quiz', '0.2985']
# Dòng 839: ['40', 'easy', '0.6', '8', 'do_quiz_harder', '0.3']
# Dòng 1154: ['41', 'easy', '0.3', '8', 'read_new_resource', '0.4']
# Dòng 1201: ['41', 'easy', '0.6', '8', 'do_quiz_same', '0.1']
# Dòng 1274: ['41', 'medium', '0.3', '8', 'read_new_resource', '0.19']
# Dòng 1554: ['42', 'easy', '0.6', '8', 'read_new_resource', '0.3940399']
