# %%
import csv

def check_q_values(file_path):
    with open(file_path, mode='r', encoding='utf-8') as file:
        reader = csv.reader(file)
        header = next(reader)  # Bỏ qua tiêu đề cột
        found = False
        
        for line_number, row in enumerate(reader, start=2):  # start=2 vì dòng 1 là header
            try:
                q_value = float(row[-1])  # Cột q_value nằm ở cuối
                if q_value > 0:
                    print(f"Dòng {line_number}: {row}")
                    found = True
            except ValueError:
                print(f"Lỗi: Không thể chuyển q_value ở dòng {line_number} thành số.")
        
        if not found:
            print("Không có dòng nào có q_value > 0.")

# Gọi hàm
check_q_values("q_table_results.csv")
# Out:
# Dòng 2: ['0', '0', '0', '0', '42', 'read_new_resource', '10.692033483270174']
# Dòng 4: ['0', '0', '0', '0', '42', 'attempt_new_quiz', '24.007134120010196']
# Dòng 7: ['0', '0', '0', '0', '38', 'read_new_resource', '19.321905388890503']
# Dòng 9: ['0', '0', '0', '0', '38', 'attempt_new_quiz', '17.62926096648389']
# Dòng 12: ['0', '0', '0', '0', '39', 'read_new_resource', '7.199114797594454']
# Dòng 14: ['0', '0', '0', '0', '39', 'attempt_new_quiz', '6.797639721853843']
# Dòng 17: ['0', '0', '0', '0', '40', 'read_new_resource', '12.460322898260092']
# Dòng 19: ['0', '0', '0', '0', '40', 'attempt_new_quiz', '6.574774578985362']
# Dòng 22: ['0', '0', '0', '0', '41', 'read_new_resource', '2.2']
# Dòng 24: ['0', '0', '0', '0', '41', 'attempt_new_quiz', '5.953058152098025']
# Dòng 1417: ['1', '4', '0', '0', '40', 'read_new_resource', '7.140237892328386']
# Dòng 1472: ['1', '4', '1', '0', '41', 'read_new_resource', '4.442340366684036']
# Dòng 1907: ['1', '9', '0', '0', '38', 'read_new_resource', '11.237130619830356']
# Dòng 1909: ['1', '9', '0', '0', '38', 'attempt_new_quiz', '12.893172323197472']
# Dòng 1912: ['1', '9', '0', '0', '39', 'read_new_resource', '6.1471692350206']
# Dòng 1914: ['1', '9', '0', '0', '39', 'attempt_new_quiz', '6.008175015057152']
# Dòng 1917: ['1', '9', '0', '0', '40', 'read_new_resource', '11.954364174063835']
# Dòng 1919: ['1', '9', '0', '0', '40', 'attempt_new_quiz', '10.290574322750947']
# Dòng 1952: ['1', '9', '1', '0', '42', 'read_new_resource', '12.469714131538655']
# Dòng 1954: ['1', '9', '1', '0', '42', 'attempt_new_quiz', '15.620390494157473']
# Dòng 1967: ['1', '9', '1', '0', '40', 'read_new_resource', '7.961026629046307']
# Dòng 1969: ['1', '9', '1', '0', '40', 'attempt_new_quiz', '7.833029165005445']
# Dòng 9062: ['10', '9', '0', '0', '38', 'read_new_resource', '8.607160704961803']
# Dòng 9064: ['10', '9', '0', '0', '38', 'attempt_new_quiz', '10.398277029586344']
# Dòng 9069: ['10', '0', '0', '0', '41', 'attempt_new_quiz', '4.157026640156277']
# Dòng 9072: ['9', '9', '0', '0', '42', 'read_new_resource', '15.903615262573576']
# Dòng 9074: ['9', '9', '0', '0', '42', 'attempt_new_quiz', '17.223995018185487']
# Dòng 9077: ['10', '9', '0', '0', '42', 'read_new_resource', '13.569622775647415']
# Dòng 9079: ['10', '9', '0', '0', '42', 'attempt_new_quiz', '11.55994240992026']
# Dòng 9082: ['9', '9', '0', '0', '38', 'read_new_resource', '11.700600812694352']
# Dòng 9084: ['9', '9', '0', '0', '38', 'attempt_new_quiz', '11.95626678856066']
# Dòng 9087: ['9', '9', '0', '0', '39', 'read_new_resource', '5.041536422639452']
# Dòng 9089: ['9', '9', '0', '0', '39', 'attempt_new_quiz', '4.837532483883367']
# Dòng 9097: ['9', '9', '0', '0', '40', 'read_new_resource', '7.256913470527795']
# Dòng 9099: ['9', '9', '0', '0', '40', 'attempt_new_quiz', '6.689425061501011']
# Dòng 9102: ['10', '9', '0', '0', '40', 'read_new_resource', '2.3698876054758498']
# Dòng 9104: ['10', '9', '0', '0', '40', 'attempt_new_quiz', '2.1529032519579774']
# Dòng 9107: ['9', '4', '0', '0', '41', 'read_new_resource', '3.3089350431162132']
# Dòng 9109: ['9', '4', '0', '0', '41', 'attempt_new_quiz', '4.5592509193']
# Dòng 9114: ['10', '4', '0', '0', '41', 'attempt_new_quiz', '5.203114099208188']
# Dòng 9119: ['9', '0', '0', '0', '43', 'attempt_new_quiz', '5.733668268930497']
# Dòng 9122: ['10', '4', '0', '0', '43', 'read_new_resource', '2.05176412754374']
# Dòng 9124: ['10', '4', '0', '0', '43', 'attempt_new_quiz', '3.919574077860427']
# Dòng 9127: ['9', '4', '0', '0', '43', 'read_new_resource', '3.788546558176411']
# Dòng 9129: ['9', '4', '0', '0', '43', 'attempt_new_quiz', '3.788546558176411']
# Dòng 9132: ['10', '9', '0', '0', '43', 'read_new_resource', '2.6708531894239806']
# Dòng 9134: ['10', '9', '0', '0', '43', 'attempt_new_quiz', '2.7241822394609']
# Dòng 9137: ['0', '0', '0', '0', '43', 'read_new_resource', '7.6582970711377']
# Dòng 9139: ['0', '0', '0', '0', '43', 'attempt_new_quiz', '15.556519705485249']
# Dòng 9142: ['10', '9', '1', '0', '42', 'read_new_resource', '1.8727824285252372']
# Dòng 9144: ['10', '9', '1', '0', '42', 'attempt_new_quiz', '4.3917213610412125']
# Dòng 9147: ['10', '9', '1', '0', '39', 'read_new_resource', '0.37479433936403994']
# Dòng 9149: ['10', '9', '1', '0', '39', 'attempt_new_quiz', '0.7645639931229915']
# Dòng 9152: ['10', '9', '1', '0', '40', 'read_new_resource', '2.1417878080473036']
# Dòng 9154: ['10', '9', '1', '0', '40', 'attempt_new_quiz', '1.5142674304383275']
# Dòng 9157: ['10', '4', '1', '0', '41', 'read_new_resource', '0.945468843207701']
# Dòng 9159: ['10', '4', '1', '0', '41', 'attempt_new_quiz', '0.5886077380593822']
# Dòng 9162: ['10', '9', '1', '0', '43', 'read_new_resource', '0.3422201634167269']
# Dòng 9164: ['10', '9', '1', '0', '43', 'attempt_new_quiz', '1.3576077873535488']
# Dòng 9167: ['10', '9', '1', '0', '38', 'read_new_resource', '0.1840704117303491']
# Dòng 9169: ['10', '9', '1', '0', '38', 'attempt_new_quiz', '0.5373504717523641']
# Dòng 9174: ['10', '0', '1', '0', '33', 'attempt_new_quiz', '2.0534426089246183']
# Dòng 9177: ['10', '4', '0', '0', '42', 'read_new_resource', '1.4472122382490105']
# Dòng 9179: ['10', '4', '0', '0', '42', 'attempt_new_quiz', '3.144848873359804']
# Dòng 9184: ['10', '0', '0', '0', '33', 'attempt_new_quiz', '2.8307975333663853']
