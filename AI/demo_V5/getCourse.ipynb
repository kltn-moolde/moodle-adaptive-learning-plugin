# %% [markdown]
# # Lấy thông tin khoá học

# %% [markdown]
# - Tư duy như sau:
#  + Cần lấy log của khoá học
#  + Cần lấy cấu trúc, thông tin khoá học
# -> API get khoá học
# -> API get danh sách thành viên trong khoá học (giáo viên và học sinh)
# -> API log của từng người trong khoá học

# %%
import requests
import json
import pandas as pd
from IPython.display import display, HTML
from bs4 import BeautifulSoup

# %%
# Cấu hình Moodle API
moodle_url = "http://localhost:8100/webservice/rest/server.php"
api_token = ""

def call_moodle_api(wsfunction, params=None):
    """
    Gọi Moodle Web Service API với hàm và tham số được chỉ định.

    Args:
        wsfunction (str): Tên hàm Web Service.
        params (dict, optional): Tham số bổ sung cho API.

    Returns:
        dict or list: Dữ liệu JSON trả về từ API hoặc None nếu có lỗi.
    """
    default_params = {
        'wstoken': api_token,
        'wsfunction': wsfunction,
        'moodlewsrestformat': 'json'
    }
    if params:
        default_params.update(params)
    
    try:
        response = requests.get(moodle_url, params=default_params)
        if response.status_code != 200:
            print(f"❌ Lỗi HTTP: {response.status_code}")
            print("Nội dung phản hồi:", response.text)
            return None
        
        data = response.json()
        if isinstance(data, dict) and 'exception' in data:
            print(f"❌ Lỗi API: {data['errorcode']}")
            print(f"Thông điệp: {data['message']}")
            return None
        
        return data
    
    except requests.exceptions.RequestException as e:
        print(f"❌ Lỗi khi gửi yêu cầu: {e}")
        return None
    except json.JSONDecodeError as e:
        print(f"❌ Lỗi phân tích JSON: {e}")
        print("Nội dung phản hồi:", response.text)
        return None

def get_all_courses():
    """
    Lấy danh sách tất cả các khóa học.

    Returns:
        list: Danh sách các khóa học hoặc None nếu có lỗi.
    """
    data = call_moodle_api('core_course_get_courses')
    return data if data else []

def get_course_contents(courseid):
    """
    Lấy chi tiết nội dung của một khóa học, bao gồm section và module.

    Args:
        courseid (int): ID của khóa học.

    Returns:
        list: Danh sách các section hoặc None nếu có lỗi.
    """
    return call_moodle_api('core_course_get_contents', {'courseid': courseid})

def get_lesson_details(lessonid):
    """
    Lấy chi tiết một bài học (lesson).

    Args:
        lessonid (int): ID của bài học.

    Returns:
        dict: Thông tin bài học hoặc None nếu có lỗi.
    """
    return call_moodle_api('mod_lesson_get_lesson', {'lessonid': lessonid})

def get_lesson_pages(lessonid):
    """
    Lấy danh sách các trang trong một bài học.

    Args:
        lessonid (int): ID của bài học.

    Returns:
        list: Danh sách các trang hoặc None nếu có lỗi.
    """
    return call_moodle_api('mod_lesson_get_pages', {'lessonid': lessonid})

def get_list_of_users_in_course(courseid):
    """
    Lấy danh sách người dùng trong một khóa học.

    Args:
        courseid (int): ID của khóa học.

    Returns:
        list: Danh sách người dùng hoặc None nếu có lỗi.
    """
    return call_moodle_api('core_enrol_get_enrolled_users', {'courseid': courseid})

# %% [markdown]
# ### Danh sách người tham gia khoá học (cả giáo viên và học sinh)

# %%
courseid = 5
users = get_list_of_users_in_course(courseid)
if users:
    for user in users:
         print(f"ID: {user['id']}, Tên: {user['fullname']}, Email: {user['email']}")
# Out:
# ❌ Lỗi API: invalidtoken
# Thông điệp: Invalid token - token not found

# %% [markdown]
# ### Cấu trúc khoá học

# %%
courseid = 5
data = get_course_contents(courseid)
print(json.dumps(data, indent=2, ensure_ascii=False))
# Out:
# [
#   {
#     "id": 33,
#     "name": "General",
#     "visible": 1,
#     "summary": "",
#     "summaryformat": 1,
#     "section": 0,
#     "hiddenbynumsections": 0,
#     "uservisible": true,
#     "component": null,
#     "itemid": null,
#     "modules": [
#       {
#         "id": 52,
#         "url": "http://localhost:8100/mod/forum/view.php?id=52",
#         "name": "Announcements",
#         "instance": 4,
#         "contextid": 80,
#         "visible": 1,
#         "uservisible": true,
#         "visibleoncoursepage": 1,
#         "modicon": "http://localhost:8100/theme/image.php?theme=boost&component=forum&rev=1753845787&image=monologo&filtericon=1",
#         "modname": "forum",
#         "purpose": "collaboration",
#         "branded": false,
#         "modplural": "Forums",
#         "availability": null,
#         "indent": 0,
#         "onclick": "",
#         "afterlink": null,
#         "activitybadge": [],
#         "customdata": "{\"trackingtype\":\"1\"}",
#         "noviewlink": false,
#         "completion": 0,
#         "downloadcontent": 1,
#         "dates": [],
#         "groupmode": 0
#       },
#       {
#         "id": 60,
#         "url": "http://localhost:8100/mod/qbank/view.php?id=60",
#         "name": "Tin 12 - Định hướng Khoa học Máy tính course question bank",
#         "instance": 2,
#         "contextid": 88,
#         "visible": 0,
#         "uservisible": true,
#         "visibleoncoursepage": 1,
#         "modicon": "http://localhost:8100/theme/image.php?theme=boost&component=qbank&rev=1753845787&image=monologo&filtericon=1",
#         "modname": "qbank",
#         "purpose": "content",
#         "branded": false,
#         "modplural": "Question banks",
#         "availability": null,
#         "indent": 0,
#         "onclick": "",
#         "afterlink": null,
#         "customdata": "\"\"",
#         "noviewlink": false,
#         "completion": 0,
#         "downloadcontent": 1,
#         "dates": [],
#         "groupmode": 0
#       }
#     ]
#   },
#   {
#     "id": 34,
#     "name": "Chủ đề 1: MÁY TÍNH VÀ XÃ HỘI TRI THỨC",
#     "visible": 1,
#     "summary": "",
#     "summaryformat": 1,
#     "section": 1,
#     "hiddenbynumsections": 0,
#     "uservisible": true,
#     "component": null,
#     "itemid": null,
#     "modules": [
#       {
#         "id": 53,
#         "name": "Bài 1: Làm quen với Trí tuệ nhân tạo",
#         "instance": 14,
#         "contextid": 81,
#         "visible": 1,
#         "uservisible": true,
#         "visibleoncoursepage": 1,
#         "modicon": "http://localhost:8100/theme/image.php?theme=boost&component=subsection&rev=1753845787&image=monologo&filtericon=1",
#         "modname": "subsection",
#         "purpose": "content",
#         "branded": false,
#         "modplural": "Subsections",
#         "availability": null,
#         "indent": 0,
#         "onclick": "",
#         "afterlink": null,
#         "customdata": "{\"sectionid\":\"38\"}",
#         "noviewlink": false,
#         "completion": 0,
#         "downloadcontent": 1,
#         "dates": [],
#         "groupmode": 0
#       },
#       {
#         "id": 54,
#         "name": "Bài 2: Trí tuệ nhân tạo trong khoa học và đời sống",
#         "instance": 15,
#         "contextid": 82,
#         "visible": 1,
#         "uservisible": true,
#         "visibleoncoursepage": 1,
#         "modicon": "http://localhost:8100/theme/image.php?theme=boost&component=subsection&rev=1753845787&image=monologo&filtericon=1",
#         "modname": "subsection",
#         "purpose": "content",
#         "branded": false,
#         "modplural": "Subsections",
#         "availability": null,
#         "indent": 0,
#         "onclick": "",
#         "afterlink": null,
#         "customdata": "{\"sectionid\":\"39\"}",
#         "noviewlink": false,
#         "completion": 0,
#         "downloadcontent": 1,
#         "dates": [],
#         "groupmode": 0
#       }
#     ]
#   },
#   {
#     "id": 35,
#     "name": "Chủ đề 2: MẠNG MÁY TÍNH VÀ INTERNET",
#     "visible": 1,
#     "summary": "",
#     "summaryformat": 1,
#     "section": 2,
#     "hiddenbynumsections": 0,
#     "uservisible": true,
#     "component": null,
#     "itemid": null,
#     "modules": [
#       {
#         "id": 55,
#         "name": "Bài 3: Một số thiết bị mạng thông dụng",
#         "instance": 16,
#         "contextid": 83,
#         "visible": 1,
#         "uservisible": true,
#         "visibleoncoursepage": 1,
#         "modicon": "http://localhost:8100/theme/image.php?theme=boost&component=subsection&rev=1753845787&image=monologo&filtericon=1",
#         "modname": "subsection",
#         "purpose": "content",
#         "branded": false,
#         "modplural": "Subsections",
#         "availability": null,
#         "indent": 0,
#         "onclick": "",
#         "afterlink": null,
#         "customdata": "{\"sectionid\":\"40\"}",
#         "noviewlink": false,
#         "completion": 0,
#         "downloadcontent": 1,
#         "dates": [],
#         "groupmode": 0
#       },
#       {
#         "id": 56,
#         "name": "Bài 4: Giao thức mạng",
#         "instance": 17,
#         "contextid": 84,
#         "visible": 1,
#         "uservisible": true,
#         "visibleoncoursepage": 1,
#         "modicon": "http://localhost:8100/theme/image.php?theme=boost&component=subsection&rev=1753845787&image=monologo&filtericon=1",
#         "modname": "subsection",
#         "purpose": "content",
#         "branded": false,
#         "modplural": "Subsections",
#         "availability": null,
#         "indent": 0,
#         "onclick": "",
#         "afterlink": null,
#         "customdata": "{\"sectionid\":\"41\"}",
#         "noviewlink": false,
#         "completion": 0,
#         "downloadcontent": 1,
#         "dates": [],
#         "groupmode": 0
#       },
#       {
#         "id": 57,
#         "name": "Bài 5: Thực hành chia sẽ tài nguyên trên mạng",
#         "instance": 18,
#         "contextid": 85,
#         "visible": 1,
#         "uservisible": true,
#         "visibleoncoursepage": 1,
#         "modicon": "http://localhost:8100/theme/image.php?theme=boost&component=subsection&rev=1753845787&image=monologo&filtericon=1",
#         "modname": "subsection",
#         "purpose": "content",
#         "branded": false,
#         "modplural": "Subsections",
#         "availability": null,
#         "indent": 0,
#         "onclick": "",
#         "afterlink": null,
#         "customdata": "{\"sectionid\":\"42\"}",
#         "noviewlink": false,
#         "completion": 0,
#         "downloadcontent": 1,
#         "dates": [],
#         "groupmode": 0
#       }
#     ]
#   },
#   {
#     "id": 36,
#     "name": "Chủ đề 3: ĐẠO ĐỨC, PHÁT LUẬT VÀ VĂN HOÁ TRONG MÔI TRƯỜNG SỐ",
#     "visible": 1,
#     "summary": "",
#     "summaryformat": 1,
#     "section": 3,
#     "hiddenbynumsections": 0,
#     "uservisible": true,
#     "component": null,
#     "itemid": null,
#     "modules": [
#       {
#         "id": 58,
#         "name": "Bài 6: Giao tiếp và ứng xử trong không gian mạng",
#         "instance": 19,
#         "contextid": 86,
#         "visible": 1,
#         "uservisible": true,
#         "visibleoncoursepage": 1,
#         "modicon": "http://localhost:8100/theme/image.php?theme=boost&component=subsection&rev=1753845787&image=monologo&filtericon=1",
#         "modname": "subsection",
#         "purpose": "content",
#         "branded": false,
#         "modplural": "Subsections",
#         "availability": null,
#         "indent": 0,
#         "onclick": "",
#         "afterlink": null,
#         "customdata": "{\"sectionid\":\"43\"}",
#         "noviewlink": false,
#         "completion": 0,
#         "downloadcontent": 1,
#         "dates": [],
#         "groupmode": 0
#       }
#     ]
#   },
#   {
#     "id": 38,
#     "name": "Bài 1: Làm quen với Trí tuệ nhân tạo",
#     "visible": 1,
#     "summary": "",
#     "summaryformat": 1,
#     "section": 4,
#     "hiddenbynumsections": 0,
#     "uservisible": true,
#     "component": "mod_subsection",
#     "itemid": 14,
#     "modules": [
#       {
#         "id": 62,
#         "url": "http://localhost:8100/mod/resource/view.php?id=62",
#         "name": "SGK_CS_Bai1",
#         "instance": 6,
#         "contextid": 90,
#         "visible": 1,
#         "uservisible": true,
#         "visibleoncoursepage": 1,
#         "modicon": "http://localhost:8100/theme/image.php?theme=boost&component=core&rev=1753845787&image=f%2Fpdf&filtericon=1",
#         "modname": "resource",
#         "purpose": "content",
#         "branded": false,
#         "modplural": "Files",
#         "availability": null,
#         "indent": 0,
#         "onclick": "",
#         "afterlink": null,
#         "activitybadge": {
#           "badgecontent": "PDF",
#           "badgestyle": "badge-none"
#         },
#         "customdata": "{\"filtericon\":true,\"displayoptions\":\"a:3:{s:10:\\\"printintro\\\";i:1;s:8:\\\"showtype\\\";i:1;s:11:\\\"filedetails\\\";a:3:{s:4:\\\"type\\\";s:12:\\\"PDF document\\\";s:8:\\\"mimetype\\\";s:15:\\\"application\\/pdf\\\";s:9:\\\"extension\\\";s:3:\\\"PDF\\\";}}\",\"display\":5}",
#         "noviewlink": false,
#         "completion": 2,
#         "completiondata": {
#           "state": 1,
#           "timecompleted": 1753848552,
#           "overrideby": null,
#           "valueused": false,
#           "hascompletion": true,
#           "isautomatic": true,
#           "istrackeduser": true,
#           "uservisible": true,
#           "details": [
#             {
#               "rulename": "completionview",
#               "rulevalue": {
#                 "status": 1,
#                 "description": "View"
#               }
#             }
#           ],
#           "isoverallcomplete": true
#         },
#         "downloadcontent": 1,
#         "dates": [],
#         "groupmode": 0,
#         "contents": [
#           {
#             "type": "file",
#             "filename": "SGK_CS_Bai1.pdf",
#             "filepath": "/",
#             "filesize": 5633933,
#             "fileurl": "http://localhost:8100/webservice/pluginfile.php?file=%2F90%2Fmod_resource%2Fcontent%2F2%2FSGK_CS_Bai1.pdf&amp;forcedownload=1",
#             "timecreated": 1753845396,
#             "timemodified": 1753845399,
#             "sortorder": 1,
#             "mimetype": "application/pdf",
#             "isexternalfile": false,
#             "userid": 2,
#             "author": "Nguyen Loc",
#             "license": "unknown"
#           }
#         ],
#         "contentsinfo": {
#           "filescount": 1,
#           "filessize": 5633933,
#           "lastmodified": 1753845399,
#           "mimetypes": [
#             "application/pdf"
#           ],
#           "repositorytype": ""
#         }
#       },
#       {
#         "id": 63,
#         "url": "http://localhost:8100/mod/hvp/view.php?id=63",
#         "name": "Video bài giảng bài 1",
#         "instance": 1,
#         "contextid": 91,
#         "visible": 1,
#         "uservisible": true,
#         "visibleoncoursepage": 1,
#         "modicon": "http://localhost:8100/theme/image.php?theme=boost&component=hvp&rev=1753845787&image=monologo&filtericon=1",
#         "modname": "hvp",
#         "purpose": "other",
#         "branded": false,
#         "modplural": "Interactive Content",
#         "availability": null,
#         "indent": 0,
#         "onclick": "",
#         "afterlink": null,
#         "customdata": "\"\"",
#         "noviewlink": false,
#         "completion": 2,
#         "completiondata": {
#           "state": 1,
#           "timecompleted": 1753848516,
#           "overrideby": null,
#           "valueused": false,
#           "hascompletion": true,
#           "isautomatic": true,
#           "istrackeduser": true,
#           "uservisible": true,
#           "details": [
#             {
#               "rulename": "completionview",
#               "rulevalue": {
#                 "status": 1,
#                 "description": "View"
#               }
#             }
#           ],
#           "isoverallcomplete": true
#         },
#         "downloadcontent": 1,
#         "dates": [],
#         "groupmode": 0
#       },
#       {
#         "id": 61,
#         "url": "http://localhost:8100/mod/quiz/view.php?id=61",
#         "name": "bài kiểm tra 1",
#         "instance": 3,
#         "contextid": 89,
#         "visible": 1,
#         "uservisible": true,
#         "visibleoncoursepage": 1,
#         "modicon": "http://localhost:8100/theme/image.php?theme=boost&component=quiz&rev=1753845787&image=monologo&filtericon=1",
#         "modname": "quiz",
#         "purpose": "assessment",
#         "branded": false,
#         "modplural": "Quizzes",
#         "availability": null,
#         "indent": 0,
#         "onclick": "",
#         "afterlink": null,
#         "customdata": "{\"customcompletionrules\":{\"completionpassorattemptsexhausted\":{\"completionpassgrade\":\"1\",\"completionattemptsexhausted\":\"1\"},\"completionminattempts\":\"0\"}}",
#         "noviewlink": false,
#         "completion": 2,
#         "completiondata": {
#           "state": 2,
#           "timecompleted": 1753848636,
#           "overrideby": null,
#           "valueused": false,
#           "hascompletion": true,
#           "isautomatic": true,
#           "istrackeduser": true,
#           "uservisible": true,
#           "details": [
#             {
#               "rulename": "completionview",
#               "rulevalue": {
#                 "status": 1,
#                 "description": "View"
#               }
#             },
#             {
#               "rulename": "completionusegrade",
#               "rulevalue": {
#                 "status": 2,
#                 "description": "Receive a grade"
#               }
#             },
#             {
#               "rulename": "completionpassgrade",
#               "rulevalue": {
#                 "status": 2,
#                 "description": "Receive a passing grade"
#               }
#             },
#             {
#               "rulename": "completionpassorattemptsexhausted",
#               "rulevalue": {
#                 "status": 1,
#                 "description": "Receive a pass grade or complete all available attempts"
#               }
#             }
#           ],
#           "isoverallcomplete": true
#         },
#         "downloadcontent": 1,
#         "dates": [],
#         "groupmode": 0
#       }
#     ]
#   },
#   {
#     "id": 39,
#     "name": "Bài 2: Trí tuệ nhân tạo trong khoa học và đời sống",
#     "visible": 1,
#     "summary": "",
#     "summaryformat": 1,
#     "section": 5,
#     "hiddenbynumsections": 0,
#     "uservisible": true,
#     "component": "mod_subsection",
#     "itemid": 15,
#     "modules": [
#       {
#         "id": 64,
#         "url": "http://localhost:8100/mod/resource/view.php?id=64",
#         "name": "SGK_CS_Bai2",
#         "instance": 7,
#         "contextid": 92,
#         "visible": 1,
#         "uservisible": true,
#         "visibleoncoursepage": 1,
#         "modicon": "http://localhost:8100/theme/image.php?theme=boost&component=core&rev=1753845787&image=f%2Fpdf&filtericon=1",
#         "modname": "resource",
#         "purpose": "content",
#         "branded": false,
#         "modplural": "Files",
#         "availability": null,
#         "indent": 0,
#         "onclick": "",
#         "afterlink": null,
#         "activitybadge": {
#           "badgecontent": "PDF",
#           "badgestyle": "badge-none"
#         },
#         "customdata": "{\"filtericon\":true,\"displayoptions\":\"a:3:{s:10:\\\"printintro\\\";i:1;s:8:\\\"showtype\\\";i:1;s:11:\\\"filedetails\\\";a:3:{s:4:\\\"type\\\";s:12:\\\"PDF document\\\";s:8:\\\"mimetype\\\";s:15:\\\"application\\/pdf\\\";s:9:\\\"extension\\\";s:3:\\\"PDF\\\";}}\",\"display\":5}",
#         "noviewlink": false,
#         "completion": 2,
#         "completiondata": {
#           "state": 1,
#           "timecompleted": 1753851637,
#           "overrideby": null,
#           "valueused": false,
#           "hascompletion": true,
#           "isautomatic": true,
#           "istrackeduser": true,
#           "uservisible": true,
#           "details": [
#             {
#               "rulename": "completionview",
#               "rulevalue": {
#                 "status": 1,
#                 "description": "View"
#               }
#             }
#           ],
#           "isoverallcomplete": true
#         },
#         "downloadcontent": 1,
#         "dates": [],
#         "groupmode": 0,
#         "contents": [
#           {
#             "type": "file",
#             "filename": "SGK_CS_Bai2.pdf",
#             "filepath": "/",
#             "filesize": 6429034,
#             "fileurl": "http://localhost:8100/webservice/pluginfile.php?file=%2F92%2Fmod_resource%2Fcontent%2F2%2FSGK_CS_Bai2.pdf&amp;forcedownload=1",
#             "timecreated": 1753850810,
#             "timemodified": 1753850814,
#             "sortorder": 1,
#             "mimetype": "application/pdf",
#             "isexternalfile": false,
#             "userid": 2,
#             "author": "Nguyen Loc",
#             "license": "unknown"
#           }
#         ],
#         "contentsinfo": {
#           "filescount": 1,
#           "filessize": 6429034,
#           "lastmodified": 1753850814,
#           "mimetypes": [
#             "application/pdf"
#           ],
#           "repositorytype": ""
#         }
#       },
#       {
#         "id": 65,
#         "url": "http://localhost:8100/mod/hvp/view.php?id=65",
#         "name": "Video bài giảng bài 2",
#         "instance": 2,
#         "contextid": 93,
#         "visible": 1,
#         "uservisible": true,
#         "visibleoncoursepage": 1,
#         "modicon": "http://localhost:8100/theme/image.php?theme=boost&component=hvp&rev=1753845787&image=monologo&filtericon=1",
#         "modname": "hvp",
#         "purpose": "other",
#         "branded": false,
#         "modplural": "Interactive Content",
#         "availability": null,
#         "indent": 0,
#         "onclick": "",
#         "afterlink": null,
#         "customdata": "\"\"",
#         "noviewlink": false,
#         "completion": 2,
#         "completiondata": {
#           "state": 1,
#           "timecompleted": 1753850962,
#           "overrideby": null,
#           "valueused": false,
#           "hascompletion": true,
#           "isautomatic": true,
#           "istrackeduser": true,
#           "uservisible": true,
#           "details": [
#             {
#               "rulename": "completionview",
#               "rulevalue": {
#                 "status": 1,
#                 "description": "View"
#               }
#             }
#           ],
#           "isoverallcomplete": true
#         },
#         "downloadcontent": 1,
#         "dates": [],
#         "groupmode": 0
#       },
#       {
#         "id": 66,
#         "url": "http://localhost:8100/mod/quiz/view.php?id=66",
#         "name": "bài kiểm tra bài 2",
#         "instance": 4,
#         "contextid": 94,
#         "visible": 1,
#         "uservisible": true,
#         "visibleoncoursepage": 1,
#         "modicon": "http://localhost:8100/theme/image.php?theme=boost&component=quiz&rev=1753845787&image=monologo&filtericon=1",
#         "modname": "quiz",
#         "purpose": "assessment",
#         "branded": false,
#         "modplural": "Quizzes",
#         "availability": null,
#         "indent": 0,
#         "onclick": "",
#         "afterlink": null,
#         "customdata": "{\"customcompletionrules\":{\"completionpassorattemptsexhausted\":[],\"completionminattempts\":\"0\"}}",
#         "noviewlink": false,
#         "completion": 2,
#         "completiondata": {
#           "state": 2,
#           "timecompleted": 1753851684,
#           "overrideby": null,
#           "valueused": false,
#           "hascompletion": true,
#           "isautomatic": true,
#           "istrackeduser": true,
#           "uservisible": true,
#           "details": [
#             {
#               "rulename": "completionview",
#               "rulevalue": {
#                 "status": 1,
#                 "description": "View"
#               }
#             },
#             {
#               "rulename": "completionusegrade",
#               "rulevalue": {
#                 "status": 2,
#                 "description": "Receive a grade"
#               }
#             },
#             {
#               "rulename": "completionpassgrade",
#               "rulevalue": {
#                 "status": 2,
#                 "description": "Receive a passing grade"
#               }
#             }
#           ],
#           "isoverallcomplete": true
#         },
#         "downloadcontent": 1,
#         "dates": [],
#         "groupmode": 0
#       }
#     ]
#   },
#   {
#     "id": 40,
#     "name": "Bài 3: Một số thiết bị mạng thông dụng",
#     "visible": 1,
#     "summary": "",
#     "summaryformat": 1,
#     "section": 6,
#     "hiddenbynumsections": 0,
#     "uservisible": true,
#     "component": "mod_subsection",
#     "itemid": 16,
#     "modules": [
#       {
#         "id": 67,
#         "url": "http://localhost:8100/mod/hvp/view.php?id=67",
#         "name": "Video bài giảng bài 3",
#         "instance": 3,
#         "contextid": 95,
#         "visible": 1,
#         "uservisible": true,
#         "visibleoncoursepage": 1,
#         "modicon": "http://localhost:8100/theme/image.php?theme=boost&component=hvp&rev=1753845787&image=monologo&filtericon=1",
#         "modname": "hvp",
#         "purpose": "other",
#         "branded": false,
#         "modplural": "Interactive Content",
#         "availability": null,
#         "indent": 0,
#         "onclick": "",
#         "afterlink": null,
#         "customdata": "\"\"",
#         "noviewlink": false,
#         "completion": 0,
#         "downloadcontent": 1,
#         "dates": [],
#         "groupmode": 0
#       },
#       {
#         "id": 68,
#         "url": "http://localhost:8100/mod/resource/view.php?id=68",
#         "name": "SGK_CS_Bai3",
#         "instance": 8,
#         "contextid": 96,
#         "visible": 1,
#         "uservisible": true,
#         "visibleoncoursepage": 1,
#         "modicon": "http://localhost:8100/theme/image.php?theme=boost&component=core&rev=1753845787&image=f%2Fpdf&filtericon=1",
#         "modname": "resource",
#         "purpose": "content",
#         "branded": false,
#         "modplural": "Files",
#         "availability": null,
#         "indent": 0,
#         "onclick": "",
#         "afterlink": null,
#         "activitybadge": {
#           "badgecontent": "PDF",
#           "badgestyle": "badge-none"
#         },
#         "customdata": "{\"filtericon\":true,\"displayoptions\":\"a:3:{s:10:\\\"printintro\\\";i:1;s:8:\\\"showtype\\\";i:1;s:11:\\\"filedetails\\\";a:3:{s:4:\\\"type\\\";s:12:\\\"PDF document\\\";s:8:\\\"mimetype\\\";s:15:\\\"application\\/pdf\\\";s:9:\\\"extension\\\";s:3:\\\"PDF\\\";}}\",\"display\":5}",
#         "noviewlink": false,
#         "completion": 0,
#         "downloadcontent": 1,
#         "dates": [],
#         "groupmode": 0,
#         "contents": [
#           {
#             "type": "file",
#             "filename": "SGK_CS_Bai3.pdf",
#             "filepath": "/",
#             "filesize": 3374342,
#             "fileurl": "http://localhost:8100/webservice/pluginfile.php?file=%2F96%2Fmod_resource%2Fcontent%2F1%2FSGK_CS_Bai3.pdf&amp;forcedownload=1",
#             "timecreated": 1753944458,
#             "timemodified": 1753944463,
#             "sortorder": 1,
#             "mimetype": "application/pdf",
#             "isexternalfile": false,
#             "userid": 2,
#             "author": "Nguyen Loc",
#             "license": "unknown"
#           }
#         ],
#         "contentsinfo": {
#           "filescount": 1,
#           "filessize": 3374342,
#           "lastmodified": 1753944463,
#           "mimetypes": [
#             "application/pdf"
#           ],
#           "repositorytype": ""
#         }
#       },
#       {
#         "id": 75,
#         "url": "http://localhost:8100/mod/quiz/view.php?id=75",
#         "name": "Trắc nghiệm bài 3",
#         "instance": 5,
#         "contextid": 103,
#         "visible": 1,
#         "uservisible": true,
#         "visibleoncoursepage": 1,
#         "modicon": "http://localhost:8100/theme/image.php?theme=boost&component=quiz&rev=1753845787&image=monologo&filtericon=1",
#         "modname": "quiz",
#         "purpose": "assessment",
#         "branded": false,
#         "modplural": "Quizzes",
#         "availability": null,
#         "indent": 0,
#         "onclick": "",
#         "afterlink": null,
#         "customdata": "\"\"",
#         "noviewlink": false,
#         "completion": 0,
#         "downloadcontent": 1,
#         "dates": [],
#         "groupmode": 0
#       }
#     ]
#   },
#   {
#     "id": 41,
#     "name": "Bài 4: Giao thức mạng",
#     "visible": 1,
#     "summary": "",
#     "summaryformat": 1,
#     "section": 7,
#     "hiddenbynumsections": 0,
#     "uservisible": true,
#     "component": "mod_subsection",
#     "itemid": 17,
#     "modules": [
#       {
#         "id": 69,
#         "url": "http://localhost:8100/mod/hvp/view.php?id=69",
#         "name": "Video bài giảng bài 4",
#         "instance": 4,
#         "contextid": 97,
#         "visible": 1,
#         "uservisible": true,
#         "visibleoncoursepage": 1,
#         "modicon": "http://localhost:8100/theme/image.php?theme=boost&component=hvp&rev=1753845787&image=monologo&filtericon=1",
#         "modname": "hvp",
#         "purpose": "other",
#         "branded": false,
#         "modplural": "Interactive Content",
#         "availability": null,
#         "indent": 0,
#         "onclick": "",
#         "afterlink": null,
#         "customdata": "\"\"",
#         "noviewlink": false,
#         "completion": 0,
#         "downloadcontent": 1,
#         "dates": [],
#         "groupmode": 0
#       },
#       {
#         "id": 70,
#         "url": "http://localhost:8100/mod/resource/view.php?id=70",
#         "name": "SGK_CS_Bai4",
#         "instance": 9,
#         "contextid": 98,
#         "visible": 1,
#         "uservisible": true,
#         "visibleoncoursepage": 1,
#         "modicon": "http://localhost:8100/theme/image.php?theme=boost&component=core&rev=1753845787&image=f%2Fpdf&filtericon=1",
#         "modname": "resource",
#         "purpose": "content",
#         "branded": false,
#         "modplural": "Files",
#         "availability": null,
#         "indent": 0,
#         "onclick": "",
#         "afterlink": null,
#         "activitybadge": {
#           "badgecontent": "PDF",
#           "badgestyle": "badge-none"
#         },
#         "customdata": "{\"filtericon\":true,\"displayoptions\":\"a:3:{s:10:\\\"printintro\\\";i:1;s:8:\\\"showtype\\\";i:1;s:11:\\\"filedetails\\\";a:3:{s:4:\\\"type\\\";s:12:\\\"PDF document\\\";s:8:\\\"mimetype\\\";s:15:\\\"application\\/pdf\\\";s:9:\\\"extension\\\";s:3:\\\"PDF\\\";}}\",\"display\":5}",
#         "noviewlink": false,
#         "completion": 0,
#         "downloadcontent": 1,
#         "dates": [],
#         "groupmode": 0,
#         "contents": [
#           {
#             "type": "file",
#             "filename": "SGK_CS_Bai4.pdf",
#             "filepath": "/",
#             "filesize": 2741972,
#             "fileurl": "http://localhost:8100/webservice/pluginfile.php?file=%2F98%2Fmod_resource%2Fcontent%2F1%2FSGK_CS_Bai4.pdf&amp;forcedownload=1",
#             "timecreated": 1753944555,
#             "timemodified": 1753944557,
#             "sortorder": 1,
#             "mimetype": "application/pdf",
#             "isexternalfile": false,
#             "userid": 2,
#             "author": "Nguyen Loc",
#             "license": "unknown"
#           }
#         ],
#         "contentsinfo": {
#           "filescount": 1,
#           "filessize": 2741972,
#           "lastmodified": 1753944557,
#           "mimetypes": [
#             "application/pdf"
#           ],
#           "repositorytype": ""
#         }
#       },
#       {
#         "id": 76,
#         "url": "http://localhost:8100/mod/quiz/view.php?id=76",
#         "name": "Trắc nghiệm bài 4",
#         "instance": 6,
#         "contextid": 104,
#         "visible": 1,
#         "uservisible": true,
#         "visibleoncoursepage": 1,
#         "modicon": "http://localhost:8100/theme/image.php?theme=boost&component=quiz&rev=1753845787&image=monologo&filtericon=1",
#         "modname": "quiz",
#         "purpose": "assessment",
#         "branded": false,
#         "modplural": "Quizzes",
#         "availability": null,
#         "indent": 0,
#         "onclick": "",
#         "afterlink": null,
#         "customdata": "\"\"",
#         "noviewlink": false,
#         "completion": 0,
#         "downloadcontent": 1,
#         "dates": [],
#         "groupmode": 0
#       }
#     ]
#   },
#   {
#     "id": 42,
#     "name": "Bài 5: Thực hành chia sẽ tài nguyên trên mạng",
#     "visible": 1,
#     "summary": "",
#     "summaryformat": 1,
#     "section": 8,
#     "hiddenbynumsections": 0,
#     "uservisible": true,
#     "component": "mod_subsection",
#     "itemid": 18,
#     "modules": [
#       {
#         "id": 71,
#         "url": "http://localhost:8100/mod/hvp/view.php?id=71",
#         "name": "Video bài giảng bài 5",
#         "instance": 5,
#         "contextid": 99,
#         "visible": 1,
#         "uservisible": true,
#         "visibleoncoursepage": 1,
#         "modicon": "http://localhost:8100/theme/image.php?theme=boost&component=hvp&rev=1753845787&image=monologo&filtericon=1",
#         "modname": "hvp",
#         "purpose": "other",
#         "branded": false,
#         "modplural": "Interactive Content",
#         "availability": null,
#         "indent": 0,
#         "onclick": "",
#         "afterlink": null,
#         "customdata": "\"\"",
#         "noviewlink": false,
#         "completion": 0,
#         "downloadcontent": 1,
#         "dates": [],
#         "groupmode": 0
#       },
#       {
#         "id": 72,
#         "url": "http://localhost:8100/mod/resource/view.php?id=72",
#         "name": "SGK_CS_Bai5",
#         "instance": 10,
#         "contextid": 100,
#         "visible": 1,
#         "uservisible": true,
#         "visibleoncoursepage": 1,
#         "modicon": "http://localhost:8100/theme/image.php?theme=boost&component=core&rev=1753845787&image=f%2Fpdf&filtericon=1",
#         "modname": "resource",
#         "purpose": "content",
#         "branded": false,
#         "modplural": "Files",
#         "availability": null,
#         "indent": 0,
#         "onclick": "",
#         "afterlink": null,
#         "activitybadge": {
#           "badgecontent": "PDF",
#           "badgestyle": "badge-none"
#         },
#         "customdata": "{\"filtericon\":true,\"displayoptions\":\"a:3:{s:10:\\\"printintro\\\";i:1;s:8:\\\"showtype\\\";i:1;s:11:\\\"filedetails\\\";a:3:{s:4:\\\"type\\\";s:12:\\\"PDF document\\\";s:8:\\\"mimetype\\\";s:15:\\\"application\\/pdf\\\";s:9:\\\"extension\\\";s:3:\\\"PDF\\\";}}\",\"display\":5}",
#         "noviewlink": false,
#         "completion": 0,
#         "downloadcontent": 1,
#         "dates": [],
#         "groupmode": 0,
#         "contents": [
#           {
#             "type": "file",
#             "filename": "SGK_CS_Bai5.pdf",
#             "filepath": "/",
#             "filesize": 3619697,
#             "fileurl": "http://localhost:8100/webservice/pluginfile.php?file=%2F100%2Fmod_resource%2Fcontent%2F1%2FSGK_CS_Bai5.pdf&amp;forcedownload=1",
#             "timecreated": 1753944613,
#             "timemodified": 1753944622,
#             "sortorder": 1,
#             "mimetype": "application/pdf",
#             "isexternalfile": false,
#             "userid": 2,
#             "author": "Nguyen Loc",
#             "license": "unknown"
#           }
#         ],
#         "contentsinfo": {
#           "filescount": 1,
#           "filessize": 3619697,
#           "lastmodified": 1753944622,
#           "mimetypes": [
#             "application/pdf"
#           ],
#           "repositorytype": ""
#         }
#       },
#       {
#         "id": 77,
#         "url": "http://localhost:8100/mod/quiz/view.php?id=77",
#         "name": "Trắc nghiệm bài 5",
#         "instance": 7,
#         "contextid": 105,
#         "visible": 1,
#         "uservisible": true,
#         "visibleoncoursepage": 1,
#         "modicon": "http://localhost:8100/theme/image.php?theme=boost&component=quiz&rev=1753845787&image=monologo&filtericon=1",
#         "modname": "quiz",
#         "purpose": "assessment",
#         "branded": false,
#         "modplural": "Quizzes",
#         "availability": null,
#         "indent": 0,
#         "onclick": "",
#         "afterlink": null,
#         "customdata": "\"\"",
#         "noviewlink": false,
#         "completion": 0,
#         "downloadcontent": 1,
#         "dates": [],
#         "groupmode": 0
#       }
#     ]
#   },
#   {
#     "id": 43,
#     "name": "Bài 6: Giao tiếp và ứng xử trong không gian mạng",
#     "visible": 1,
#     "summary": "",
#     "summaryformat": 1,
#     "section": 9,
#     "hiddenbynumsections": 0,
#     "uservisible": true,
#     "component": "mod_subsection",
#     "itemid": 19,
#     "modules": [
#       {
#         "id": 73,
#         "url": "http://localhost:8100/mod/hvp/view.php?id=73",
#         "name": "Video bài giảng bài 6",
#         "instance": 6,
#         "contextid": 101,
#         "visible": 1,
#         "uservisible": true,
#         "visibleoncoursepage": 1,
#         "modicon": "http://localhost:8100/theme/image.php?theme=boost&component=hvp&rev=1753845787&image=monologo&filtericon=1",
#         "modname": "hvp",
#         "purpose": "other",
#         "branded": false,
#         "modplural": "Interactive Content",
#         "availability": null,
#         "indent": 0,
#         "onclick": "",
#         "afterlink": null,
#         "customdata": "\"\"",
#         "noviewlink": false,
#         "completion": 0,
#         "downloadcontent": 1,
#         "dates": [],
#         "groupmode": 0
#       },
#       {
#         "id": 74,
#         "url": "http://localhost:8100/mod/resource/view.php?id=74",
#         "name": "SGK_CS_Bai6",
#         "instance": 11,
#         "contextid": 102,
#         "visible": 1,
#         "uservisible": true,
#         "visibleoncoursepage": 1,
#         "modicon": "http://localhost:8100/theme/image.php?theme=boost&component=core&rev=1753845787&image=f%2Fpdf&filtericon=1",
#         "modname": "resource",
#         "purpose": "content",
#         "branded": false,
#         "modplural": "Files",
#         "availability": null,
#         "indent": 0,
#         "onclick": "",
#         "afterlink": null,
#         "activitybadge": {
#           "badgecontent": "PDF",
#           "badgestyle": "badge-none"
#         },
#         "customdata": "{\"filtericon\":true,\"displayoptions\":\"a:3:{s:10:\\\"printintro\\\";i:1;s:8:\\\"showtype\\\";i:1;s:11:\\\"filedetails\\\";a:3:{s:4:\\\"type\\\";s:12:\\\"PDF document\\\";s:8:\\\"mimetype\\\";s:15:\\\"application\\/pdf\\\";s:9:\\\"extension\\\";s:3:\\\"PDF\\\";}}\",\"display\":5}",
#         "noviewlink": false,
#         "completion": 0,
#         "downloadcontent": 1,
#         "dates": [],
#         "groupmode": 0,
#         "contents": [
#           {
#             "type": "file",
#             "filename": "SGK_CS_Bai6.pdf",
#             "filepath": "/",
#             "filesize": 2717822,
#             "fileurl": "http://localhost:8100/webservice/pluginfile.php?file=%2F102%2Fmod_resource%2Fcontent%2F1%2FSGK_CS_Bai6.pdf&amp;forcedownload=1",
#             "timecreated": 1753944696,
#             "timemodified": 1753944699,
#             "sortorder": 1,
#             "mimetype": "application/pdf",
#             "isexternalfile": false,
#             "userid": 2,
#             "author": "Nguyen Loc",
#             "license": "unknown"
#           }
#         ],
#         "contentsinfo": {
#           "filescount": 1,
#           "filessize": 2717822,
#           "lastmodified": 1753944699,
#           "mimetypes": [
#             "application/pdf"
#           ],
#           "repositorytype": ""
#         }
#       },
#       {
#         "id": 78,
#         "url": "http://localhost:8100/mod/quiz/view.php?id=78",
#         "name": "Trắc nghiệm bài 6",
#         "instance": 8,
#         "contextid": 106,
#         "visible": 1,
#         "uservisible": true,
#         "visibleoncoursepage": 1,
#         "modicon": "http://localhost:8100/theme/image.php?theme=boost&component=quiz&rev=1753845787&image=monologo&filtericon=1",
#         "modname": "quiz",
#         "purpose": "assessment",
#         "branded": false,
#         "modplural": "Quizzes",
#         "availability": null,
#         "indent": 0,
#         "onclick": "",
#         "afterlink": null,
#         "customdata": "\"\"",
#         "noviewlink": false,
#         "completion": 0,
#         "downloadcontent": 1,
#         "dates": [],
#         "groupmode": 0
#       }
#     ]
#   }
# ]
