# %%
import csv

def check_q_values(file_path):
    with open(file_path, mode='r', encoding='utf-8') as file:
        reader = csv.reader(file)
        header = next(reader)  # Bỏ qua tiêu đề cột
        found = False
        
        for line_number, row in enumerate(reader, start=2):  # start=2 vì dòng 1 là header
            try:
                q_value = float(row[-1])  # Cột q_value nằm ở cuối
                if q_value > 0:
                    print(f"Dòng {line_number}: {row}")
                    found = True
            except ValueError:
                print(f"Lỗi: Không thể chuyển q_value ở dòng {line_number} thành số.")
        
        if not found:
            print("Không có dòng nào có q_value > 0.")

# Gọi hàm
check_q_values("q_table_results.csv")
# Out:
# Dòng 4: ['0', '0', '0', '0', '42', 'attempt_new_quiz', '6.128543760971478']
# Dòng 7: ['0', '0', '0', '0', '38', 'read_new_resource', '2.343']
# Dòng 1417: ['1', '4', '0', '0', '40', 'read_new_resource', '0.5']
# Dòng 1472: ['1', '4', '1', '0', '41', 'read_new_resource', '0.7000000000000001']
# Dòng 1907: ['1', '9', '0', '0', '38', 'read_new_resource', '4.040648244790394']
# Dòng 1909: ['1', '9', '0', '0', '38', 'attempt_new_quiz', '4.85015066308271']
# Dòng 1912: ['1', '9', '0', '0', '39', 'read_new_resource', '2.0710553197215296']
# Dòng 1914: ['1', '9', '0', '0', '39', 'attempt_new_quiz', '1.860137844334838']
# Dòng 1917: ['1', '9', '0', '0', '40', 'read_new_resource', '1.94509']
# Dòng 1919: ['1', '9', '0', '0', '40', 'attempt_new_quiz', '1.2728719141740632']
# Dòng 1952: ['1', '9', '1', '0', '42', 'read_new_resource', '4.016566528982793']
# Dòng 1954: ['1', '9', '1', '0', '42', 'attempt_new_quiz', '7.770930180980898']
# Dòng 1967: ['1', '9', '1', '0', '40', 'read_new_resource', '2.521488195916925']
# Dòng 1969: ['1', '9', '1', '0', '40', 'attempt_new_quiz', '1.8369184912146712']
# Dòng 9902: ['9', '9', '0', '0', '42', 'read_new_resource', '1.2197242625571156']
# Dòng 9904: ['9', '9', '0', '0', '42', 'attempt_new_quiz', '0.7824926154946048']
# Dòng 9917: ['9', '9', '0', '0', '40', 'read_new_resource', '1.000565842344166']
# Dòng 9919: ['9', '9', '0', '0', '40', 'attempt_new_quiz', '0.61003743462195']
# Dòng 11004: ['9', '0', '0', '0', '43', 'attempt_new_quiz', '0.6108840238688287']
# Dòng 11009: ['9', '4', '0', '0', '43', 'attempt_new_quiz', '0.7000000000000001']
