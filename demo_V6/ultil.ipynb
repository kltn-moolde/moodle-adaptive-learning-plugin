# %%
import csv

def check_q_values(file_path):
    with open(file_path, mode='r', encoding='utf-8') as file:
        reader = csv.reader(file)
        header = next(reader)  # Bỏ qua tiêu đề cột
        found = False
        
        for line_number, row in enumerate(reader, start=2):  # start=2 vì dòng 1 là header
            try:
                q_value = float(row[-1])  # Cột q_value nằm ở cuối
                if q_value > 0:
                    print(f"Dòng {line_number}: {row}")
                    found = True
            except ValueError:
                print(f"Lỗi: Không thể chuyển q_value ở dòng {line_number} thành số.")
        
        if not found:
            print("Không có dòng nào có q_value > 0.")

# Gọi hàm
check_q_values("q_table_results.csv")
# Out:
# Dòng 4: ['0', '0', '0', '0', '42', 'attempt_new_quiz', '10.337677032341006']
# Dòng 7: ['0', '0', '0', '0', '38', 'read_new_resource', '4.297910861701183']
# Dòng 1137: ['1', '4', '0', '0', '40', 'read_new_resource', '1.1201171']
# Dòng 1527: ['1', '9', '0', '0', '38', 'read_new_resource', '0.5254618453080191']
# Dòng 1529: ['1', '9', '0', '0', '38', 'attempt_new_quiz', '0.5088266878696932']
# Dòng 1537: ['1', '9', '0', '0', '40', 'read_new_resource', '3.400415412805619']
# Dòng 1539: ['1', '9', '0', '0', '40', 'attempt_new_quiz', '2.240914611105204']
# Dòng 1562: ['1', '9', '1', '0', '42', 'read_new_resource', '0.1317822813553938']
# Dòng 1564: ['1', '9', '1', '0', '42', 'attempt_new_quiz', '0.36277207432864317']
# Dòng 1577: ['1', '9', '1', '0', '40', 'read_new_resource', '0.2298186312501643']
# Dòng 1579: ['1', '9', '1', '0', '40', 'attempt_new_quiz', '0.2208107654352938']
