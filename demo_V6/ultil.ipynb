# %%
import csv

def check_q_values(file_path):
    with open(file_path, mode='r', encoding='utf-8') as file:
        reader = csv.reader(file)
        header = next(reader)  # Bỏ qua tiêu đề cột
        found = False
        
        for line_number, row in enumerate(reader, start=2):  # start=2 vì dòng 1 là header
            try:
                q_value = float(row[-1])  # Cột q_value nằm ở cuối
                if q_value > 0:
                    print(f"Dòng {line_number}: {row}")
                    found = True
            except ValueError:
                print(f"Lỗi: Không thể chuyển q_value ở dòng {line_number} thành số.")
        
        if not found:
            print("Không có dòng nào có q_value > 0.")

# Gọi hàm
check_q_values("q_table_results.csv")
# Out:
# Dòng 4: ['0', '0', '0', '0', '42', 'attempt_new_quiz', '26.873834914582137']
# Dòng 7: ['0', '0', '0', '0', '38', 'read_new_resource', '14.5048516802831']
# Dòng 1417: ['1', '4', '0', '0', '40', 'read_new_resource', '5.363967543945649']
# Dòng 1472: ['1', '4', '1', '0', '41', 'read_new_resource', '3.5381286481160505']
# Dòng 1907: ['1', '9', '0', '0', '38', 'read_new_resource', '8.942281261256197']
# Dòng 1909: ['1', '9', '0', '0', '38', 'attempt_new_quiz', '10.135543018769017']
# Dòng 1912: ['1', '9', '0', '0', '39', 'read_new_resource', '5.355739951250382']
# Dòng 1914: ['1', '9', '0', '0', '39', 'attempt_new_quiz', '5.208967535390003']
# Dòng 1917: ['1', '9', '0', '0', '40', 'read_new_resource', '10.356338029194095']
# Dòng 1919: ['1', '9', '0', '0', '40', 'attempt_new_quiz', '8.488708581646392']
# Dòng 1952: ['1', '9', '1', '0', '42', 'read_new_resource', '9.884173172031414']
# Dòng 1954: ['1', '9', '1', '0', '42', 'attempt_new_quiz', '12.522103021024911']
# Dòng 1967: ['1', '9', '1', '0', '40', 'read_new_resource', '6.774909424345072']
# Dòng 1969: ['1', '9', '1', '0', '40', 'attempt_new_quiz', '6.538687478322425']
# Dòng 9062: ['10', '9', '0', '0', '38', 'read_new_resource', '1.9548851552167748']
# Dòng 9064: ['10', '9', '0', '0', '38', 'attempt_new_quiz', '2.0965047362556724']
# Dòng 9069: ['10', '0', '0', '0', '41', 'attempt_new_quiz', '1.118426476279681']
# Dòng 9072: ['9', '9', '0', '0', '42', 'read_new_resource', '10.860467136808603']
# Dòng 9074: ['9', '9', '0', '0', '42', 'attempt_new_quiz', '12.597912733770125']
# Dòng 9077: ['10', '9', '0', '0', '42', 'read_new_resource', '6.98793803567046']
# Dòng 9079: ['10', '9', '0', '0', '42', 'attempt_new_quiz', '7.0730332518683445']
# Dòng 9082: ['9', '9', '0', '0', '38', 'read_new_resource', '7.355585678154738']
# Dòng 9084: ['9', '9', '0', '0', '38', 'attempt_new_quiz', '7.433926380104268']
# Dòng 9087: ['9', '9', '0', '0', '39', 'read_new_resource', '4.036352295996944']
# Dòng 9089: ['9', '9', '0', '0', '39', 'attempt_new_quiz', '3.696225206268772']
# Dòng 9097: ['9', '9', '0', '0', '40', 'read_new_resource', '6.395383632228406']
# Dòng 9099: ['9', '9', '0', '0', '40', 'attempt_new_quiz', '5.013413597707562']
# Dòng 9102: ['10', '9', '0', '0', '40', 'read_new_resource', '4.347713339495957']
# Dòng 9104: ['10', '9', '0', '0', '40', 'attempt_new_quiz', '3.0755808905871302']
# Dòng 9107: ['9', '4', '0', '0', '41', 'read_new_resource', '2.102008993']
# Dòng 9109: ['9', '4', '0', '0', '41', 'attempt_new_quiz', '3.2799130000000005']
# Dòng 9119: ['9', '0', '0', '0', '43', 'attempt_new_quiz', '3.569700128655']
# Dòng 9122: ['10', '4', '0', '0', '43', 'read_new_resource', '1.355']
# Dòng 9124: ['10', '4', '0', '0', '43', 'attempt_new_quiz', '3.0210795514209017']
# Dòng 9127: ['9', '4', '0', '0', '43', 'read_new_resource', '2.3048801157895']
# Dòng 9129: ['9', '4', '0', '0', '43', 'attempt_new_quiz', '2.3048801157895']
# Dòng 9132: ['10', '9', '0', '0', '43', 'read_new_resource', '0.0087302688191188']
# Dòng 9134: ['10', '9', '0', '0', '43', 'attempt_new_quiz', '0.014213462134879']
